# %% [markdown]
# ## Apresentaçõa do Projeto

# %% [markdown]
# #### “Digitar um CNPJ e obter resultado” (requisito atendido)

# %%
cnpj="28196878"
Import-Csv .\reports\model1_scores_20260109.csv |
  Where-Object {$_.cnpj_raiz -eq $cnpj} |
  Format-List
# Out:
#   Cell In[1], line 1
#     $cnpj="28196878"
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# “Basta informar o CNPJ para obter o score de risco e os principais fatores associados.”
